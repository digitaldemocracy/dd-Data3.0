# %%
import pickle
import pandas as pd
from dateutil.relativedelta import relativedelta
from unidecode import unidecode
import numpy as np

from functools import partial

from ScrapeStaffBestRefactored import *

# %reload_ext autoreload
# %autoreload 2

# %%
leg_lop_df = pickle.load(open('leg_lop_df.p', 'rb'))
# cpy_leg_lop_df = pickle.load(open('cpy_leg_lop_df.p', 'rb'))

existing_staff_df = pickle.load(open('existing_staff_df.p', 'rb'))

# leg_lop_row = pickle.load(open('leg_lop_row.p', 'rb'))
# offices_df = pickle.load(open('offices_df.p', 'rb'))

# staff_info = pickle.load(open('staff_info.p', 'rb'))

# matched_rows_df = pickle.load(open('matched_rows_df.p', 'rb'))

# matched_leg_terms_df = pickle.load(open('matched_leg_terms_df.p', 'rb'))

# db_leg_term_infos = pickle.load(open('SavedLegTermInfo.p', 'rb'))
# db_leg_term_df = pd.DataFrame(db_leg_term_infos)
# db_leg_term_df = pickle.load(open('db_leg_term_df.p', 'rb'))

g_missed_staff = pickle.load(open('g_missed_staff.p', 'rb'))

# match_df = pickle.load(open('match_df.p', 'rb'))

# %%
bad_dates = leg_lop_df['last_seen'] > leg_lop_df['end_date']

# %%
sum(bad_dates)
# Out:
# 124

# %%
leg_lop_df[leg_lop_df['last'].apply(lambda x: 'barnuevo' in x)]
# Out:
#       first middle           last   hire_date   file_date  term_year   house  \
# 50    angel   None   barnuevo jr.  2007-03-26  2011-02-28     2011.0  Senate
# 921   angel   None  barnuevo  jr.  2007-03-26  2011-06-30     2011.0  Senate
# 3579  angel   None   barnuevo  jr  2007-03-26  2013-02-28     2013.0  Senate
# 5115  angel   None   barnuevo jr.  2013-01-01  2013-06-30     2013.0  Senate
#
#           pid   row                      file assoc_type         assoc office  \
# 50    90556.0  51.0  SenateStaff 02-28-11.csv        leg  alex padilla   None
# 921   91420.0  60.0  SenateStaff 06-30-11.csv        leg  alex padilla   None
# 3579  93676.0  60.0  SenateStaff 02-28-13.csv        leg  alex padilla   None
# 5115  90556.0  60.0  SenateStaff 06-30-13.csv        leg  alex padilla   None
#
#       lo_id  leg_pid leg_first leg_middle leg_last    end_date   last_seen  \
# 50      NaN  38302.0      Alex       None  Padilla  2011-08-28  2012-06-30
# 921     NaN  38302.0      Alex       None  Padilla  2011-12-30  2011-06-30
# 3579    NaN  38302.0      Alex       None  Padilla  2013-08-28  2013-02-28
# 5115    NaN  38302.0      Alex       None  Padilla  2014-12-31  2014-02-28
#
#                                                                  file_appearances  \
# 50     SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 921                                                      SenateStaff 06-30-11.csv
# 3579                                                     SenateStaff 02-28-13.csv
# 5115                            SenateStaff 06-30-13.csv SenateStaff 02-28-14.csv
#
#      set_at_end primary_source
# 50        False           True
# 921       False           True
# 3579      False           True
# 5115      False           True

# %%
row1 = leg_lop_df[leg_lop_df['last'].apply(lambda x: 'barnuevo' in x)].iloc[0]
row2 = leg_lop_df[leg_lop_df['last'].apply(lambda x: 'barnuevo' in x)].iloc[1]

# %%
cmp_names(row1['first'], row1['middle'], row1['last'], row2['first'], row2['middle'], row2['last'])
# Out:
# False

# %%
row1['first'] == row2['first']
# Out:
# True

# %%
row1['middle'] == row2['middle']
# Out:
# True

# %%
for l1, l2 in zip(row1['last'], row2['last']):
    print(l1, l2)
    print(l1 == l2)
# Out:
# b b
# True
# a a
# True
# r r
# True
# n n
# True
# u u
# True
# e e
# True
# v v
# True
# o o
# True
#
# True
# j
# False
# r j
# False
# . r
# False

# %%
leg_lop_df[bad_dates]
# Out:
#            first middle                last   hire_date   file_date  \
# 50         angel   None        barnuevo jr.  2007-03-26  2011-02-28
# 85      meredith   None               borak  2000-02-11  2011-02-28
# 112        cindy   None             burrell  1991-05-16  2011-02-28
# 135       shanda   None            chaudhry  2003-09-15  2011-02-28
# 152     margaret   None             collins  1982-12-06  2011-02-28
# 161      susanna   None              cooper  2006-12-04  2011-02-28
# 170         eric   None             csizmar  2009-01-05  2011-02-28
# 174         anna   None             damiani  2008-12-01  2011-02-28
# 192    alexandra   None             doniach  2010-11-22  2011-02-28
# 197       carmen   None             ducusin  2004-12-06  2011-02-28
# 232        susan   None                finn  2011-02-28  2011-02-28
# 252        junay   None       gardner logan  2008-12-01  2011-02-28
# 281        brian   None               green  2011-02-28  2011-02-28
# 292         matt   None             guthrie  2008-12-01  2011-02-28
# 295     jennifer   None              guzman  2007-05-01  2011-02-28
# 320        laura   None                hein  2004-12-06  2011-02-28
# 366        gemma   None             jimenez  2007-03-22  2011-02-28
# 399      darlene   None               kirch  2004-12-06  2011-02-28
# 408       arcadi   None             kolchak  2009-06-29  2011-02-28
# 412       cheryl   None          kozachenko  2007-05-09  2011-02-28
# 414      arielle   None          kubu-jones  2011-01-03  2011-02-28
# 422       tahiza   None  landeros de reilly  2011-02-28  2011-02-28
# 470     satinder   None               malhi  2005-09-16  2011-02-28
# 486     jennifer   None           masterson  2008-12-01  2011-02-28
# 508       cheryl   None           mclachlan  2005-08-01  2011-02-28
# 513        frine   None             medrano  2010-12-06  2011-02-28
# 527      suzanne   None              miller  2005-04-04  2011-02-28
# 533         hema   None               mohan  2005-03-14  2011-02-28
# 565          ana   None              negron  2002-07-01  2011-02-28
# 575     patricia   None             o'brien  2010-12-06  2011-02-28
# ...          ...    ...                 ...         ...         ...
# 3905      daniel   None           lieberman  2013-01-01  2013-02-28
# 3958      cheryl   None           mclachlan  2013-01-01  2013-02-28
# 3962       frine   None             medrano  2013-01-01  2013-02-28
# 3991       tyler   None             munzing  2013-01-01  2013-02-28
# 3996         iso   None            nakasato  2013-01-01  2013-02-28
# 4000      stacey   None               neese  2013-01-01  2013-02-28
# 4001     roberto   None             negrete  2013-01-01  2013-02-28
# 4021      robert   None        olmstead iii  2013-02-28  2013-02-28
# 4024       laura   None              ortega  2013-01-01  2013-02-28
# 4044      judith   None                pina  2013-02-28  2013-02-28
# 4067        mark   None              reeder  2013-01-01  2013-02-28
# 4075      meriam   None             reynosa  2013-01-01  2013-02-28
# 4076      darius   None                rice  2013-01-01  2013-02-28
# 4082      louise   None             rishoff  2012-12-01  2013-02-28
# 4092       jaime   None           rodriguez  2013-01-01  2013-02-28
# 4094    veronica   None           rodriguez  2013-02-28  2013-02-28
# 4108      sharon   None              runner  2013-02-05  2013-02-28
# 4112      ranier   None           sabeniano  2013-02-28  2013-02-28
# 4165       barry   None           steinhart  2013-02-28  2013-02-28
# 4169     russell   None              stiger  2013-02-28  2013-02-28
# 4191     baydsar   None           thomasian  2013-01-01  2013-02-28
# 4199      jeanne   None                tran  2013-01-01  2013-02-28
# 4218    adrianna   None          villanueva  2013-02-28  2013-02-28
# 4228  alexandria   None                wara  2012-12-03  2013-02-28
# 4245     bethany   None            westfall  2012-12-03  2013-02-28
# 4251       april   None              whytus  2013-01-01  2013-02-28
# 4256    kathleen   None              wilson  2013-02-28  2013-02-28
# 4259        cory   None             wolbach  2012-12-03  2013-02-28
# 4268     douglas   None              yoakam  2013-01-01  2013-02-28
# 5014   francisco   None              torres  2013-01-07  2013-02-28
#
#       term_year     house      pid    row                        file  \
# 50       2011.0    Senate  90556.0   51.0    SenateStaff 02-28-11.csv
# 85       2011.0    Senate  90591.0   86.0    SenateStaff 02-28-11.csv
# 112      2011.0    Senate  90618.0  113.0    SenateStaff 02-28-11.csv
# 135      2011.0    Senate  90641.0  136.0    SenateStaff 02-28-11.csv
# 152      2011.0    Senate  90658.0  153.0    SenateStaff 02-28-11.csv
# 161      2011.0    Senate  90667.0  162.0    SenateStaff 02-28-11.csv
# 170      2011.0    Senate  90676.0  171.0    SenateStaff 02-28-11.csv
# 174      2011.0    Senate  90680.0  175.0    SenateStaff 02-28-11.csv
# 192      2011.0    Senate  90698.0  193.0    SenateStaff 02-28-11.csv
# 197      2011.0    Senate  90703.0  198.0    SenateStaff 02-28-11.csv
# 232      2011.0    Senate  90738.0  235.0    SenateStaff 02-28-11.csv
# 252      2011.0    Senate  90758.0  255.0    SenateStaff 02-28-11.csv
# 281      2011.0    Senate  90787.0  284.0    SenateStaff 02-28-11.csv
# 292      2011.0    Senate  90798.0  295.0    SenateStaff 02-28-11.csv
# 295      2011.0    Senate  90801.0  298.0    SenateStaff 02-28-11.csv
# 320      2011.0    Senate  90826.0  323.0    SenateStaff 02-28-11.csv
# 366      2011.0    Senate  90872.0  371.0    SenateStaff 02-28-11.csv
# 399      2011.0    Senate  90905.0  405.0    SenateStaff 02-28-11.csv
# 408      2011.0    Senate  90914.0  414.0    SenateStaff 02-28-11.csv
# 412      2011.0    Senate  90918.0  418.0    SenateStaff 02-28-11.csv
# 414      2011.0    Senate  90920.0  420.0    SenateStaff 02-28-11.csv
# 422      2011.0    Senate  90928.0  428.0    SenateStaff 02-28-11.csv
# 470      2011.0    Senate  90976.0  477.0    SenateStaff 02-28-11.csv
# 486      2011.0    Senate  90992.0  493.0    SenateStaff 02-28-11.csv
# 508      2011.0    Senate  91014.0  515.0    SenateStaff 02-28-11.csv
# 513      2011.0    Senate  91019.0  520.0    SenateStaff 02-28-11.csv
# 527      2011.0    Senate  91033.0  534.0    SenateStaff 02-28-11.csv
# 533      2011.0    Senate  91039.0  540.0    SenateStaff 02-28-11.csv
# 565      2011.0    Senate  91070.0  572.0    SenateStaff 02-28-11.csv
# 575      2011.0    Senate  91080.0  582.0    SenateStaff 02-28-11.csv
# ...         ...       ...      ...    ...                         ...
# 3905     2013.0    Senate  93037.0  481.0    SenateStaff 02-28-13.csv
# 3958     2013.0    Senate  91014.0  555.0    SenateStaff 02-28-13.csv
# 3962     2013.0    Senate  91019.0  560.0    SenateStaff 02-28-13.csv
# 3991     2013.0    Senate  93069.0  603.0    SenateStaff 02-28-13.csv
# 3996     2013.0    Senate  92492.0  608.0    SenateStaff 02-28-13.csv
# 4000     2013.0    Senate  91068.0  613.0    SenateStaff 02-28-13.csv
# 4001     2013.0    Senate  91069.0  614.0    SenateStaff 02-28-13.csv
# 4021     2013.0    Senate  93888.0  642.0    SenateStaff 02-28-13.csv
# 4024     2013.0    Senate  91092.0  647.0    SenateStaff 02-28-13.csv
# 4044     2013.0    Senate  93899.0  675.0    SenateStaff 02-28-13.csv
# 4067     2013.0    Senate  91149.0  707.0    SenateStaff 02-28-13.csv
# 4075     2013.0    Senate  91158.0  715.0    SenateStaff 02-28-13.csv
# 4076     2013.0    Senate  91159.0  716.0    SenateStaff 02-28-13.csv
# 4082     2013.0    Senate  93911.0  723.0    SenateStaff 02-28-13.csv
# 4092     2013.0    Senate  91174.0  736.0    SenateStaff 02-28-13.csv
# 4094     2013.0    Senate  93171.0  738.0    SenateStaff 02-28-13.csv
# 4108     2013.0    Senate  93921.0  756.0    SenateStaff 02-28-13.csv
# 4112     2013.0    Senate  93094.0  760.0    SenateStaff 02-28-13.csv
# 4165     2013.0    Senate  91717.0  837.0    SenateStaff 02-28-13.csv
# 4169     2013.0    Senate  91720.0  842.0    SenateStaff 02-28-13.csv
# 4191     2013.0    Senate  91732.0  873.0    SenateStaff 02-28-13.csv
# 4199     2013.0    Senate  93114.0  886.0    SenateStaff 02-28-13.csv
# 4218     2013.0    Senate  91748.0  912.0    SenateStaff 02-28-13.csv
# 4228     2013.0    Senate  93974.0  923.0    SenateStaff 02-28-13.csv
# 4245     2013.0    Senate  93984.0  947.0    SenateStaff 02-28-13.csv
# 4251     2013.0    Senate  93190.0  956.0    SenateStaff 02-28-13.csv
# 4256     2013.0    Senate  91373.0  962.0    SenateStaff 02-28-13.csv
# 4259     2013.0    Senate  93989.0  966.0    SenateStaff 02-28-13.csv
# 4268     2013.0    Senate  93131.0  982.0    SenateStaff 02-28-13.csv
# 5014     2013.0  Assembly  94268.0  993.0  AssemblyStaff 02-28-13.csv
#
#      assoc_type                      assoc office  lo_id  leg_pid  \
# 50          leg               alex padilla   None    NaN  38302.0
# 85          leg                fran pavley   None    NaN    104.0
# 112         leg              doug la malfa   None    NaN  38298.0
# 135         leg            curren d. price   None    NaN  38303.0
# 152         leg           ellen m. corbett   None    NaN  38290.0
# 161         leg          darrell steinberg   None    NaN  38306.0
# 170         leg                   bob huff   None    NaN    105.0
# 174         leg                  mark leno   None    NaN     60.0
# 192         leg              leland y. yee   None    NaN  38312.0
# 197         leg            christine kehoe   None    NaN  38297.0
# 232         leg          darrell steinberg   None    NaN  38306.0
# 252         leg                   bob huff   None    NaN    105.0
# 281         leg              kevin de leon   None    NaN    102.0
# 292         leg            tony strickland   None    NaN  38307.0
# 295         leg                  mark leno   None    NaN     60.0
# 320         leg            christine kehoe   None    NaN  38297.0
# 366         leg              a lex padilla   None    NaN  38302.0
# 399         leg                 bob dutton   None    NaN  38293.0
# 408         leg  elaine kontominas alquist   None    NaN  38287.0
# 412         leg            christine kehoe   None    NaN  38297.0
# 414         leg               noreen evans   None    NaN  38295.0
# 422         leg               ed hernandez   None    NaN    103.0
# 470         leg            mark desaulnier   None    NaN  38292.0
# 486         leg            tony strickland   None    NaN  38307.0
# 508         leg                jean fuller   None    NaN     49.0
# 513         leg              kevin de leon   None    NaN    102.0
# 527         leg                mark wyland   None    NaN  38311.0
# 533         leg        s. joseph  simitian   None    NaN  38305.0
# 565         leg         darrell  steinberg   None    NaN  38306.0
# 575         leg              tom berryhill   None    NaN     54.0
# ...         ...                        ...    ...    ...      ...
# 3905        leg              leland y. yee   None    NaN  38312.0
# 3958        leg                jean fuller   None    NaN     49.0
# 3962        leg              kevin de leon   None    NaN    102.0
# 3991        leg          anthony  cannella   None    NaN     61.0
# 3996        leg               ed hernandez   None    NaN    103.0
# 4000        leg                   bob huff   None    NaN    105.0
# 4001        leg               alex padilla   None    NaN  38302.0
# 4021        leg                jim nielsen   None    NaN     68.0
# 4024        leg              tom berryhill   None    NaN     54.0
# 4044        leg               ricardo lara   None    NaN    107.0
# 4067        leg                mark wyland   None    NaN  38311.0
# 4075        leg              ellen corbett   None    NaN  38290.0
# 4076        leg               mimi walters   None    NaN  38309.0
# 4082        leg                fran pavley   None    NaN    104.0
# 4092        leg              ron  calderon   None    NaN  38289.0
# 4094        leg                 jerry hill   None    NaN     66.0
# 4108        leg                 ted gaines   None    NaN     24.0
# 4112        leg                 jerry hill   None    NaN     66.0
# 4165        leg                  mark leno   None    NaN     60.0
# 4169        leg              kevin de leon   None    NaN    102.0
# 4191        leg              kevin de leon   None    NaN    102.0
# 4199        leg                lou  correa   None    NaN  38291.0
# 4218        leg              kevin de leon   None    NaN    102.0
# 4228        leg                  jim beall   None    NaN     92.0
# 4245        leg        william  w. monning   None    NaN     25.0
# 4251        leg            mark desaulnier   None    NaN  38292.0
# 4256        leg                 ted gaines   None    NaN     24.0
# 4259        leg                 jerry hill   None    NaN     66.0
# 4268        leg                   bob huff   None    NaN    105.0
# 5014        leg                      gomez   None    NaN     80.0
#
#               leg_first leg_middle    leg_last    end_date   last_seen  \
# 50                 Alex       None     Padilla  2011-08-28  2012-06-30
# 85                 Fran       None      Pavley  2011-08-28  2012-06-30
# 112                Doug       None    La Malfa  2011-08-28  2012-06-30
# 135              Curren       None       Price  2011-08-28  2012-01-31
# 152               Ellen       None     Corbett  2011-08-28  2012-01-31
# 161             Darrell       None   Steinberg  2011-06-29  2012-06-30
# 170                 Bob       None        Huff  2011-06-29  2012-06-30
# 174                Mark       None        Leno  2011-08-28  2012-06-30
# 192              Leland       None         Yee  2011-08-28  2012-01-31
# 197           Christine       None       Kehoe  2011-06-29  2012-06-30
# 232             Darrell       None   Steinberg  2011-08-28  2012-06-30
# 252                 Bob       None        Huff  2011-08-28  2012-06-30
# 281               Kevin       None     De Leon  2011-08-28  2012-06-30
# 292                Tony       None  Strickland  2011-08-28  2012-06-30
# 295                Mark       None        Leno  2011-08-28  2012-06-30
# 320           Christine       None       Kehoe  2011-08-28  2012-06-30
# 366                Alex       None     Padilla  2011-08-28  2012-06-30
# 399                 Bob       None      Dutton  2011-08-28  2012-06-30
# 408   Elaine Kontominas       None     Alquist  2011-08-28  2012-01-31
# 412           Christine       None       Kehoe  2011-08-28  2012-01-31
# 414              Noreen       None       Evans  2011-08-28  2012-06-30
# 422                  Ed       None   Hernandez  2011-08-28  2012-06-30
# 470                Mark       None  DeSaulnier  2011-08-28  2012-06-30
# 486                Tony       None  Strickland  2011-08-28  2012-06-30
# 508                Jean       None      Fuller  2011-08-28  2012-06-30
# 513               Kevin       None     De Leon  2011-08-28  2012-06-30
# 527                Mark       None      Wyland  2011-08-28  2012-06-30
# 533                 Joe       None    Simitian  2011-08-28  2012-06-30
# 565             Darrell       None   Steinberg  2011-08-28  2012-06-30
# 575                 Tom       None   Berryhill  2011-08-28  2012-06-30
# ...                 ...        ...         ...         ...         ...
# 3905             Leland       None         Yee  2013-08-28  2014-02-28
# 3958               Jean       None      Fuller  2013-08-28  2014-02-28
# 3962              Kevin       None     De Leon  2013-08-28  2014-02-28
# 3991            Anthony       None    Cannella  2013-08-28  2014-02-28
# 3996                 Ed       None   Hernandez  2013-08-28  2014-02-28
# 4000                Bob       None        Huff  2013-08-28  2014-02-28
# 4001               Alex       None     Padilla  2013-08-28  2014-02-28
# 4021                Jim       None     Nielsen  2013-08-28  2014-02-28
# 4024                Tom       None   Berryhill  2013-06-29  2014-02-28
# 4044            Ricardo       None        Lara  2013-08-28  2014-02-28
# 4067               Mark       None      Wyland  2013-08-28  2014-02-28
# 4075              Ellen       None     Corbett  2013-08-28  2014-02-28
# 4076               Mimi       None     Walters  2013-08-28  2014-02-28
# 4082               Fran       None      Pavley  2013-08-28  2014-02-28
# 4092             Ronald       None    Calderon  2013-08-28  2014-02-28
# 4094              Jerry       None        Hill  2013-08-28  2014-02-28
# 4108                Ted       None      Gaines  2013-06-29  2014-02-28
# 4112              Jerry       None        Hill  2013-08-28  2014-02-28
# 4165               Mark       None        Leno  2013-08-28  2014-02-28
# 4169              Kevin       None     De Leon  2013-06-29  2014-02-28
# 4191              Kevin       None     De Leon  2013-08-28  2014-02-28
# 4199                Lou       None      Correa  2013-08-28  2014-02-28
# 4218              Kevin       None     De Leon  2013-08-28  2014-02-28
# 4228                Jim       None       Beall  2013-08-28  2014-02-28
# 4245               Bill       None     Monning  2013-08-28  2014-02-28
# 4251               Mark       None  DeSaulnier  2013-08-28  2014-02-28
# 4256                Ted       None      Gaines  2013-06-29  2014-02-28
# 4259              Jerry       None        Hill  2013-06-29  2014-02-28
# 4268                Bob       None        Huff  2013-06-29  2014-02-28
# 5014              Jimmy       None       Gomez  2013-06-29  2014-02-28
#
#                                                                  file_appearances  \
# 50     SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 85     SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 112    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 135                             SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv
# 152                             SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv
# 161    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 170    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 174    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 192                             SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv
# 197    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 232    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 252    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 281    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 292    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 295    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 320    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 366    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 399    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 408                             SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv
# 412                             SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv
# 414    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 422    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 470    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 486    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 508    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 513    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 527    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 533    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 565    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# 575    SenateStaff 02-28-11.csv SenateStaff 01-31-12.csv SenateStaff 06-30-12.csv
# ...                                                                           ...
# 3905                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 3958                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 3962                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 3991                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 3996                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4000                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4001                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4021                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4024                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4044                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4067                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4075                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4076                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4082                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4092                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4094                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4108                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4112                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4165                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4169                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4191                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4199                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4218                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4228                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4245                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4251                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4256                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4259                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 4268                            SenateStaff 02-28-13.csv SenateStaff 02-28-14.csv
# 5014                        AssemblyStaff 02-28-13.csv AssemblyStaff 02-28-14.csv
#
#      set_at_end primary_source
# 50        False           True
# 85        False           True
# 112       False           True
# 135       False           True
# 152       False           True
# 161       False           True
# 170       False           True
# 174       False           True
# 192       False           True
# 197       False           True
# 232       False           True
# 252       False           True
# 281       False           True
# 292       False           True
# 295       False           True
# 320       False           True
# 366       False           True
# 399       False           True
# 408       False           True
# 412       False           True
# 414       False           True
# 422       False           True
# 470       False           True
# 486       False           True
# 508       False           True
# 513       False           True
# 527       False           True
# 533       False           True
# 565       False           True
# 575       False           True
# ...         ...            ...
# 3905      False           True
# 3958      False           True
# 3962      False           True
# 3991      False           True
# 3996      False           True
# 4000      False           True
# 4001      False           True
# 4021      False           True
# 4024      False           True
# 4044      False           True
# 4067      False           True
# 4075      False           True
# 4076      False           True
# 4082      False           True
# 4092      False           True
# 4094      False           True
# 4108      False           True
# 4112      False           True
# 4165      False           True
# 4169      False           True
# 4191      False           True
# 4199      False           True
# 4218      False           True
# 4228      False           True
# 4245      False           True
# 4251      False           True
# 4256      False           True
# 4259      False           True
# 4268      False           True
# 5014      False           True
#
# [124 rows x 23 columns]

# %%
leg_lop_df[leg_lop_df.pid == 81950]
# Out:
#       first middle          last   hire_date   file_date  term_year   house  \
# 50    angel   None  barnuevo jr.  2007-03-26  2011-02-28     2011.0  Senate
# 5115  angel   None  barnuevo jr.  2013-01-01  2013-06-30     2013.0  Senate
#
#           pid   row                      file      ...               assoc  \
# 50    81950.0  51.0  SenateStaff 02-28-11.csv      ...        alex padilla
# 5115  81950.0  60.0  SenateStaff 06-30-13.csv      ...        alex padilla
#
#      office lo_id  leg_pid  leg_first leg_middle leg_last    end_date  \
# 50     None   NaN  38302.0       Alex       None  Padilla  2011-08-28
# 5115   None   NaN  38302.0       Alex       None  Padilla  2014-12-31
#
#        last_seen primary_source
# 50    2012-06-30           True
# 5115  2014-02-28           True
#
# [2 rows x 21 columns]

# %%
leg_lop_df[leg_lop_df.pid == 74196]
# Out:
#       first middle          last   hire_date   file_date  term_year   house  \
# 50    angel   None  barnuevo jr.  2007-03-26  2011-02-28     2011.0  Senate
# 5007  angel   None  barnuevo jr.  2013-01-01  2013-06-30     2013.0  Senate
#
#           pid   row                      file      ...               assoc  \
# 50    74196.0  51.0  SenateStaff 02-28-11.csv      ...        alex padilla
# 5007  74196.0  60.0  SenateStaff 06-30-13.csv      ...        alex padilla
#
#      office lo_id  leg_pid  leg_first leg_middle leg_last    end_date  \
# 50     None   NaN  38302.0       Alex       None  Padilla  2011-08-28
# 5007   None   NaN  38302.0       Alex       None  Padilla  2014-12-31
#
#        last_seen primary_source
# 50    2012-06-30           True
# 5007  2014-02-28           True
#
# [2 rows x 21 columns]

# %%
leg_lop_df[leg_lop_df.pid == 74231]
# Out:
#          first middle   last   hire_date   file_date  term_year   house  \
# 85    meredith   None  borak  2000-02-11  2011-02-28     2011.0  Senate
# 3554  meredith   None  borak  2013-01-01  2013-02-28     2013.0  Senate
# 5828  meredith   None  borak  2014-02-28  2014-02-28     2013.0  Senate
#
#           pid   row                      file      ...        \
# 85    74231.0  86.0  SenateStaff 02-28-11.csv      ...
# 3554  74231.0  97.0  SenateStaff 02-28-13.csv      ...
# 5828  74231.0  94.0  SenateStaff 02-28-14.csv      ...
#
#                           assoc                     office   lo_id  leg_pid  \
# 85                  fran pavley                       None     NaN    104.0
# 3554                fran pavley                       None     NaN    104.0
# 5828  legislative travel office  legislative travel office  3552.0      NaN
#
#       leg_first leg_middle leg_last    end_date   last_seen primary_source
# 85         Fran       None   Pavley  2011-08-28  2012-06-30           True
# 3554       Fran       None   Pavley  2013-12-30  2013-06-30           True
# 5828       None       None     None  2015-12-30  2015-06-30           True
#
# [3 rows x 21 columns]

# %%
backward_dates = leg_lop_df['hire_date'] >= leg_lop_df['end_date']
sum(backward_dates)
# Out:
# 0

# %%
def check_overlaps(row, cpy_leg_lop_df):
    out = False
    matched_rows = cpy_leg_lop_df[(cpy_leg_lop_df.pid == row['pid']) &
                                  (row.name != cpy_leg_lop_df.index) &
                                  (row['hire_date'] <= cpy_leg_lop_df.hire_date) &
                                  (row['end_date'] >= cpy_leg_lop_df.hire_date)]

    if len(matched_rows.index):
        out = True
    matched_rows = cpy_leg_lop_df[(cpy_leg_lop_df.pid == row['pid']) &
                                  (row.name != cpy_leg_lop_df.index) &
                                  (row['hire_date'] <= cpy_leg_lop_df.end_date) &
                                  (row['end_date'] >= cpy_leg_lop_df.end_date)]

    if len(matched_rows.index):
        out = True
    matched_rows = cpy_leg_lop_df[(cpy_leg_lop_df.pid == row['pid']) &
                                  (row.name != cpy_leg_lop_df.index) &
                                  (row['hire_date'] >= cpy_leg_lop_df.hire_date) &
                                  (row['end_date'] <= cpy_leg_lop_df.end_date)]

    if len(matched_rows.index):
        out = True
    return out

# %%
cpy_leg_lop_df = leg_lop_df.copy()

# %%
overlaps = leg_lop_df.apply(lambda row: check_overlaps(row, cpy_leg_lop_df), axis=1)

# %%
sum(overlaps)
# Out:
# 5

# %%
pd.set_option('display.width', pd.util.terminal.get_terminal_size()[0])

# %%
pd.option_context('display.max_rows', 999, 'display.max_columns', 5)

# %%
pd.set_option('display.max_columns', None)

# %%
leg_lop_df[overlaps]
# Out:
#           first middle    last   hire_date   file_date  term_year     house  \
# 4895     sandra   None   perez  2013-01-01  2013-02-28     2013.0  Assembly
# 6272     sandra   None   perez  2014-02-14  2014-02-28     2013.0    Senate
# 6273     sandra   None   perez  2013-01-01  2014-02-28     2013.0    Senate
# 7215  francisco   None  torres  2015-02-28  2015-02-28     2015.0  Assembly
# 7908  francisco   None  torres  2015-02-28  2015-02-28     2015.0    Senate
#
#           pid     row                        file assoc_type  \
# 4895  83955.0   826.0  AssemblyStaff 02-28-13.csv        leg
# 6272  83955.0   653.0    SenateStaff 02-28-14.csv     office
# 6273  83955.0   654.0    SenateStaff 02-28-14.csv     office
# 7215  85662.0  1107.0   AssemblyStaff 2-28-15.csv        leg
# 7908  85662.0   773.0    SenateStaff 02-28-15.csv        leg
#
#                           assoc                     office   lo_id  leg_pid  \
# 4895                blumenfield                       None     NaN  38316.0
# 6272  senate office of research  senate office of research  4229.0      NaN
# 6273     budget & fiscal review     budget & fiscal review  4221.0      NaN
# 7215                      gomez                       None     NaN     80.0
# 7908               loni hancock                       None     NaN     98.0
#
#      leg_first leg_middle     leg_last    end_date   last_seen primary_source
# 4895    Robert       None  Blumenfield  2013-08-28  2013-02-28           True
# 6272      None       None         None  2015-12-30  2015-06-30           True
# 6273      None       None         None  2015-12-30  2015-06-30           True
# 7215     Jimmy       None        Gomez  2015-08-28  2015-02-28           True
# 7908      Loni       None      Hancock  2015-12-30  2015-06-30           True

# %%
leg_lop_df[leg_lop_df.pid == 85662]
# Out:
#           first middle    last   hire_date   file_date  term_year     house  \
# 5014  francisco   None  torres  2013-01-07  2013-02-28     2013.0  Assembly
# 5494  francisco   None  torres  2013-06-30  2013-06-30     2013.0    Senate
# 7215  francisco   None  torres  2015-02-28  2015-02-28     2015.0  Assembly
# 7908  francisco   None  torres  2015-02-28  2015-02-28     2015.0    Senate
#
#           pid     row                        file assoc_type         assoc  \
# 5014  85662.0   993.0  AssemblyStaff 02-28-13.csv        leg         gomez
# 5494  85662.0   888.0    SenateStaff 06-30-13.csv        leg  loni hancock
# 7215  85662.0  1107.0   AssemblyStaff 2-28-15.csv        leg         gomez
# 7908  85662.0   773.0    SenateStaff 02-28-15.csv        leg  loni hancock
#
#      office  lo_id  leg_pid leg_first leg_middle leg_last    end_date  \
# 5014   None    NaN     80.0     Jimmy       None    Gomez  2013-06-29
# 5494   None    NaN     98.0      Loni       None  Hancock  2014-12-31
# 7215   None    NaN     80.0     Jimmy       None    Gomez  2015-08-28
# 7908   None    NaN     98.0      Loni       None  Hancock  2015-12-30
#
#        last_seen primary_source
# 5014  2014-02-28           True
# 5494  2014-02-28           True
# 7215  2015-02-28           True
# 7908  2015-06-30           True

# %%
leg_lop_df[overlaps & (leg_lop_df.end_date.apply(lambda x: x.year < 2015))]
# Out:
#        first middle   last   hire_date   file_date  term_year     house  \
# 4895  sandra   None  perez  2013-01-01  2013-02-28     2013.0  Assembly
#
#           pid    row                        file      ...              assoc  \
# 4895  83955.0  826.0  AssemblyStaff 02-28-13.csv      ...        blumenfield
#
#      office lo_id  leg_pid  leg_first leg_middle     leg_last    end_date  \
# 4895   None   NaN  38316.0     Robert       None  Blumenfield  2013-08-28
#
#        last_seen primary_source
# 4895  2013-02-28           True
#
# [1 rows x 21 columns]

# %%
leg_lop_df[overlaps & pd.notnull(leg_lop_df.leg_pid)]
# Out:
#           first middle    last   hire_date   file_date  term_year     house  \
# 4895     sandra   None   perez  2013-01-01  2013-02-28     2013.0  Assembly
# 7215  francisco   None  torres  2015-02-28  2015-02-28     2015.0  Assembly
# 7908  francisco   None  torres  2015-02-28  2015-02-28     2015.0    Senate
#
#           pid     row                        file      ...        \
# 4895  83955.0   826.0  AssemblyStaff 02-28-13.csv      ...
# 7215  85662.0  1107.0   AssemblyStaff 2-28-15.csv      ...
# 7908  85662.0   773.0    SenateStaff 02-28-15.csv      ...
#
#              assoc office lo_id  leg_pid  leg_first leg_middle     leg_last  \
# 4895   blumenfield   None   NaN  38316.0     Robert       None  Blumenfield
# 7215         gomez   None   NaN     80.0      Jimmy       None        Gomez
# 7908  loni hancock   None   NaN     98.0       Loni       None      Hancock
#
#         end_date   last_seen primary_source
# 4895  2013-08-28  2013-02-28           True
# 7215  2015-08-28  2015-02-28           True
# 7908  2015-12-30  2015-06-30           True
#
# [3 rows x 21 columns]

# %%
leg_lop_df[overlaps & (leg_lop_df.pid == 76445)]
# Out:
#         first middle      last   hire_date   file_date  term_year   house  \
# 7499  rebecca   None  tennison  2015-02-28  2015-02-28     2015.0  Senate
# 7905  rebecca   None  tennison  2015-06-30  2015-06-30     2015.0  Senate
#
#           pid    row                      file      ...        \
# 7499  76445.0  761.0  SenateStaff 02-28-15.csv      ...
# 7905  76445.0  780.0   SenateStaff 6-30-15.csv      ...
#
#                          assoc                    office   lo_id  leg_pid  \
# 7499  21st senatorial district  21st senatorial district  3887.0      NaN
# 7905             sharon runner                      None     NaN   4656.0
#
#       leg_first leg_middle leg_last    end_date   last_seen primary_source
# 7499       None       None     None  2015-08-28  2015-02-28           True
# 7905     Sharon       None   Runner  2015-12-30  2015-06-30           True
#
# [2 rows x 21 columns]

# %%
leg_lop_row = leg_lop_df.ix[7499]

# %%
correct_overlap_helper(leg_lop_row, cpy_leg_lop_df)
# Out:
# C:\Users\andre_000\Documents\GitHub\dd-Data3.0\Python_Scripts\UsedForUpdate\ImportLegStaffData\ScrapeStaffBestRefactored.py:1011: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   matched_rows_df = cpy_leg_lop_df[(leg_lop_row['pid'] == cpy_leg_lop_df.pid) &
# True

# %%
update_end(dates())

# %%
matched_rows_df = cpy_leg_lop_df[(int(leg_lop_row['pid']) == cpy_leg_lop_df.pid) &
                                     (leg_lop_row['hire_date'] < cpy_leg_lop_df.hire_date) &
                                     (leg_lop_row['end_date'] > cpy_leg_lop_df.hire_date)]

# %%
matched_rows_df
# Out:
#         first middle      last   hire_date   file_date  term_year   house  \
# 7905  rebecca   None  tennison  2015-06-30  2015-06-30     2015.0  Senate
#
#           pid    row                     file      ...                assoc  \
# 7905  76445.0  780.0  SenateStaff 6-30-15.csv      ...        sharon runner
#
#      office lo_id  leg_pid  leg_first leg_middle leg_last    end_date  \
# 7905   None   NaN   4656.0     Sharon       None   Runner  2015-12-30
#
#        last_seen primary_source
# 7905  2015-06-30           True
#
# [1 rows x 21 columns]

# %%
l = [[1,2]] * 5 + [[3, 4]]

# %%
df = pd.DataFrame(l, columns=['A', 'B'])

# %%
df
# Out:
#    A  B
# 0  1  2
# 1  1  2
# 2  1  2
# 3  1  2
# 4  1  2
# 5  3  4

# %%
df.iloc[:, :1]
# Out:
#    A
# 0  1
# 1  1
# 2  1
# 3  1
# 4  1
# 5  3

# %%
def f(df):
    row = df.loc[df.A == 3]
    print(row)
    row.iloc[0]['A'], row.iloc[0]['B'] = 10, 15

# %%
f(df)
# Out:
#    A  B
# 5  3  4

# %%
df
# Out:
#    A  B
# 0  1  2
# 1  1  2
# 2  1  2
# 3  1  2
# 4  1  2
# 5  3  4

# %%
l = [1]
l += [datetime.date(2012, 1, 1)]
l
# Out:
# [1, datetime.date(2012, 1, 1)]

# %%
def inner_f(row):
    row['A'] = 5
#     print(type(row))
#     print(row)

# %%
def outer_f(row):
    inner_f(row)
    return row

# %%
l = [[pd.Series([], dtype='object'), 2]] * 3
l
# Out:
# [[Series([], dtype: object), 2],
#  [Series([], dtype: object), 2],
#  [Series([], dtype: object), 2]]

# %%
df = pd.DataFrame(l, columns=['A', 'B'])

# %%
df.iloc[0]['A'].add('hi')
# Out:
# Series([], dtype: object)

# %%
df
# Out:
#                            A  B
# 0  Series([], dtype: object)  2
# 1  Series([], dtype: object)  2
# 2  Series([], dtype: object)  2

# %%
df.apply(lambda row: outer_f(row), axis=1)
# Out:
#    A  B
# 0  5  2
# 1  5  2
# 2  5  2
